# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url_template = "http://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=5415&Year=2012&Month=3&timeframe=1&submit=Download+Data"

# %%
weather_mar2012 = pd.read_csv(url_template,index_col='Date/Time',parse_dates=True,encoding='latin1')

# %%
weather_mar2012
# Out:
#                      ï»¿"Longitude (x)"  Latitude (y)  \
# Date/Time
# 2012-03-01 00:00:00              -73.75         45.47
# 2012-03-01 01:00:00              -73.75         45.47
# 2012-03-01 02:00:00              -73.75         45.47
# 2012-03-01 03:00:00              -73.75         45.47
# 2012-03-01 04:00:00              -73.75         45.47
# ...                                 ...           ...
# 2012-03-31 19:00:00              -73.75         45.47
# 2012-03-31 20:00:00              -73.75         45.47
# 2012-03-31 21:00:00              -73.75         45.47
# 2012-03-31 22:00:00              -73.75         45.47
# 2012-03-31 23:00:00              -73.75         45.47
#
#                                                Station Name  Climate ID  Year  \
# Date/Time
# 2012-03-01 00:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-03-01 01:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# ...

# %%
weather_mar2012["Temp (Â°C)"].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %%
weather_mar2012=weather_mar2012.dropna(axis=1,how="any")
weather_mar2012
# Out:
#                      ï»¿"Longitude (x)"  Latitude (y)  \
# Date/Time
# 2012-03-01 00:00:00              -73.75         45.47
# 2012-03-01 01:00:00              -73.75         45.47
# 2012-03-01 02:00:00              -73.75         45.47
# 2012-03-01 03:00:00              -73.75         45.47
# 2012-03-01 04:00:00              -73.75         45.47
# ...                                 ...           ...
# 2012-03-31 19:00:00              -73.75         45.47
# 2012-03-31 20:00:00              -73.75         45.47
# 2012-03-31 21:00:00              -73.75         45.47
# 2012-03-31 22:00:00              -73.75         45.47
# 2012-03-31 23:00:00              -73.75         45.47
#
#                                                Station Name  Climate ID  Year  \
# Date/Time
# 2012-03-01 00:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# 2012-03-01 01:00:00  MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A     7025250  2012
# ...

# %%
weather_mar2012["Station Name"].value_counts()
# Out:
# MONTREAL/PIERRE ELLIOTT TRUDEAU INTL A    744
# Name: Station Name, dtype: int64

# %%
weather_mar2012=weather_mar2012.drop(["Latitude (y)","Station Name","Climate ID","Year","Month"],axis=1)
weather_mar2012
# Out:
#                      ï»¿"Longitude (x)"  Day   Time  Temp (Â°C)  \
# Date/Time
# 2012-03-01 00:00:00              -73.75    1  00:00        -5.5
# 2012-03-01 01:00:00              -73.75    1  01:00        -5.7
# 2012-03-01 02:00:00              -73.75    1  02:00        -5.4
# 2012-03-01 03:00:00              -73.75    1  03:00        -4.7
# 2012-03-01 04:00:00              -73.75    1  04:00        -5.4
# ...                                 ...  ...    ...         ...
# 2012-03-31 19:00:00              -73.75   31  19:00         5.9
# 2012-03-31 20:00:00              -73.75   31  20:00         4.4
# 2012-03-31 21:00:00              -73.75   31  21:00         2.6
# 2012-03-31 22:00:00              -73.75   31  22:00         2.7
# 2012-03-31 23:00:00              -73.75   31  23:00         1.5
#
#                      Dew Point Temp (Â°C)  Rel Hum (%)  Wind Spd (km/h)  \
# Date/Time
# 2012-03-01 00:00:00                  -9.7           72               24
# ...

# %%
weather_mar2012.columns=["dell","day","time","temp","dew_temp","rel_num","wind","visibility","stn_press","weather"]

# %%
weather_mar2012
# Out:
#                       dell  day   time  temp  dew_temp  rel_num  wind  \
# Date/Time
# 2012-03-01 00:00:00 -73.75    1  00:00  -5.5      -9.7       72    24
# 2012-03-01 01:00:00 -73.75    1  01:00  -5.7      -8.7       79    26
# 2012-03-01 02:00:00 -73.75    1  02:00  -5.4      -8.3       80    28
# 2012-03-01 03:00:00 -73.75    1  03:00  -4.7      -7.7       79    28
# 2012-03-01 04:00:00 -73.75    1  04:00  -5.4      -7.8       83    35
# ...                    ...  ...    ...   ...       ...      ...   ...
# 2012-03-31 19:00:00 -73.75   31  19:00   5.9      -8.0       36     4
# 2012-03-31 20:00:00 -73.75   31  20:00   4.4      -7.2       43     9
# 2012-03-31 21:00:00 -73.75   31  21:00   2.6      -6.3       52     7
# 2012-03-31 22:00:00 -73.75   31  22:00   2.7      -6.7       50     0
# 2012-03-31 23:00:00 -73.75   31  23:00   1.5      -6.9       54     0
#
#                      visibility  stn_press weather
# Date/Time
# 2012-03-01 00:00:00         4.0     100.97    Snow
# ...

# %%
weather_mar2012=weather_mar2012.drop(["dell"],axis=1)
weather_mar2012
# Out:
#                      day   time  temp  dew_temp  rel_num  wind  visibility  \
# Date/Time
# 2012-03-01 00:00:00    1  00:00  -5.5      -9.7       72    24         4.0
# 2012-03-01 01:00:00    1  01:00  -5.7      -8.7       79    26         2.4
# 2012-03-01 02:00:00    1  02:00  -5.4      -8.3       80    28         4.8
# 2012-03-01 03:00:00    1  03:00  -4.7      -7.7       79    28         4.0
# 2012-03-01 04:00:00    1  04:00  -5.4      -7.8       83    35         1.6
# ...                  ...    ...   ...       ...      ...   ...         ...
# 2012-03-31 19:00:00   31  19:00   5.9      -8.0       36     4        25.0
# 2012-03-31 20:00:00   31  20:00   4.4      -7.2       43     9        25.0
# 2012-03-31 21:00:00   31  21:00   2.6      -6.3       52     7        25.0
# 2012-03-31 22:00:00   31  22:00   2.7      -6.7       50     0        25.0
# 2012-03-31 23:00:00   31  23:00   1.5      -6.9       54     0        25.0
#
#                      stn_press weather
# Date/Time
# ...

# %%
weather_mar2012["temp"].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %%
weather_mar2012["wind"].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %%
different_weather=weather_mar2012["weather"].value_counts()

# %%
different_weather.plot(kind="bar",figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
weather_mar2012["dew_temp"].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date/Time'>

# %%
visibility=weather_mar2012["visibility"].value_counts()
visibility
# Out:
# 25.0    275
# 48.3    172
# 24.1    121
# 12.9     24
# 4.8      18
# 16.1     16
# 6.4      15
# 9.7      13
# 8.0      13
# 19.3     12
# 2.4      10
# 4.0       9
# 0.2       8
# 3.2       7
# 0.6       6
# 1.6       6
# 1.2       5
# 11.3      4
# 2.8       3
# 2.0       3
# 0.8       2
# 1.0       2
# Name: visibility, dtype: int64

# %%
visibility.plot(kind="bar",figsize=(15,10))
# Out:
# <AxesSubplot:>
