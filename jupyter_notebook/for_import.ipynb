# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# %matplotlib notebook
x = np.arange(0, math.pi * 2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_title("sine wawe")
ax.set_xlabel("angle")
ax.set_ylabel("sine")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Lx = np.arange(0, math.pi * 2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_title("sine wawe")
ax.set_xlabel("angle")
ax.set_ylabel("sine")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3bbf7c6ca6b3> in <module>
#       1 Lx = np.arange(0, math.pi * 2, 0.05)
# ----> 2 y = np.sin(x)
#       3 fig = plt.figure()
#       4 ax = fig.add_axes([0, 0, 1, 1])
#       5 ax.plot(x, y)
#
# NameError: name 'x' is not defined
